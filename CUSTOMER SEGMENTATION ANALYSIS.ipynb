# %% [markdown]
# # CUSTOMER SEGMENTATION ANALYSIS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"C:\Users\sweth\OneDrive\Pictures\Desktop\Test Jupyter\Mall_Customers.csv")
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df.drop('CustomerID', axis=1, inplace=True)

# %%
encoder = LabelEncoder()
df['Gender'] = encoder.fit_transform(df['Gender'])

gender_mappings = {index: label for index, label in enumerate(encoder.classes_)}
gender_mappings
# Out:
# {0: 'Female', 1: 'Male'}

# %%
sns.distplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Annual Income (k$)'])
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Density'>

# %%
sns.distplot(df['Spending Score (1-100)'])
# Out:
# <Axes: xlabel='Spending Score (1-100)', ylabel='Density'>

# %%
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.scatterplot(x=df['Annual Income (k$)'], y=df['Spending Score (1-100)'])
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %%
fig = plt.figure(figsize=(20,15))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df['Age'], df['Annual Income (k$)'], df['Spending Score (1-100)'], c='red', s=50)
ax.scatter(df['Age'], df['Annual Income (k$)'], df['Spending Score (1-100)'], c='green', s=50)
ax.scatter(df['Age'], df['Annual Income (k$)'], df['Spending Score (1-100)'], c='blue', s=50)
ax.scatter(df['Age'], df['Annual Income (k$)'], df['Spending Score (1-100)'], c='brown', s=50)
ax.scatter(df['Age'], df['Annual Income (k$)'], df['Spending Score (1-100)'], c='orange', s=50)
ax.view_init(30, 190)
ax.set_xlabel('Age')
ax.set_ylabel('Annual Income')
ax.set_zlabel('Spending Score')
plt.show()
